# %% [markdown]
# # PHWR U233 Tight
# This notebook is intended to compute the neutron energy spectrum and conversion ratio for a PHWR similar to the baseline example, but fueled instead with U-233 and tight lattice.

# %%
import openmc
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
# define the fuel material
fuel = openmc.Material(name='fuel');
fuel.set_density('g/cm3',10.45);
# use atom fractions for 4 a/o U-233.
# estimate based on 4 a/o U-235 materials.xml file
fuel.add_nuclide('U233',0.040491);
fuel.add_nuclide('U234',0.000362);
fuel.add_nuclide('U236',0.0001855);
fuel.add_nuclide('U238',0.9589619);
fuel.add_nuclide('O16',2.0);

# ignore the gap gas (negligible impact on neutron energy)

# just use elemental Zirconium for clad.
clad = openmc.Material(name='clad');
clad.add_element('Zr',1);
clad.set_density('g/cm3',6.0);

mod = openmc.Material(name='moderator');
mod.add_element('O',1);
mod.add_nuclide('H2',2);
mod.set_density('g/cm3',0.712); #high temperature density
mod.add_s_alpha_beta('c_D_in_D2O');

# create Materials object and export to xml
materials = openmc.Materials([fuel,clad,mod]);
materials.export_to_xml();

# %%
# define the pin cell geometry
h_core = 500.;
h_fuel = 426.7;

r_o = 0.819/2.; #cm, fuel outer radius
r_ci = r_o +  0.008255; # clad inner radius 
r_co = 0.95/2.; # clad outer radius

P_D = 1.1;

pitch = P_D*(2*r_co);

#fuel cylinder
fuel_cyl = openmc.model.RightCircularCylinder([0.,0.,-h_fuel/2.],
                                             h_fuel,r_o);
fuel.volume = np.pi*(r_o**2)*h_fuel;

# clad inner cylinder
cladi_cyl = openmc.model.RightCircularCylinder([0.,0.,-h_fuel/2.],
                                              h_fuel,r_ci);
# clad outer cylinder
clado_cyl = openmc.model.RightCircularCylinder([0.,0.,-h_fuel/2.],
                                              h_fuel,r_co);
# pin cell container
core_cell = openmc.model.RectangularParallelepiped(-pitch/2.,pitch/2.,
                                                  -pitch/2.,pitch/2.,
                                                  -h_core/2.,h_core/2.,
                                                  boundary_type='reflective');


fuel_cell = openmc.Cell();
fuel_cell.region = -fuel_cyl
fuel_cell.fill = fuel;

gap_cell = openmc.Cell();
gap_cell.region = +fuel_cyl & -cladi_cyl;
gap_cell.fill = None; # same as "void"

clad_cell = openmc.Cell();
clad_cell.region = +cladi_cyl & -clado_cyl;
clad_cell.fill = clad;

mod_cell = openmc.Cell();
mod_cell.region = +clado_cyl & -core_cell;
mod_cell.fill = mod;

root_univ = openmc.Universe();
root_univ.add_cells([fuel_cell,gap_cell,clad_cell,mod_cell]);

geometry = openmc.Geometry();
geometry.root_universe = root_univ;

geometry.export_to_xml();

# %%
colors = {}
colors[fuel]='yellow'
colors[mod] = 'blue'
colors[clad] = 'grey'

root_univ.plot(width=(pitch,pitch),pixels=[400,400],
               color_by='material',colors=colors);

# %%
# create tally to determine flux energy spectrum in the fuel

cell_filter = openmc.CellFilter(fuel_cell);

# set up energy bins
N = 1001;
energy_bins = np.logspace(-3,7,num=N);
energy_filter = openmc.EnergyFilter(values=energy_bins);

# establish flux tally
flux = openmc.Tally(name='flux');
flux.scores = ['flux'];
flux.filters = [cell_filter,energy_filter];

# create a tally to estimate conversion ratio
# use cell_filter as before
u238_capture = openmc.Tally(name='u238_total_capture');
u238_capture.scores = ['(n,gamma)'];
u238_capture.nuclides=['U238']; #take this to be the only fertile nuclide
efilter_values = [0.0, 1.0, 3.0e4, 14.0e6]; # OpenMC energy units are eV
efilter_capture = openmc.EnergyFilter(values=efilter_values);
u238_capture.filters = [cell_filter, efilter_capture];

u233_abs = openmc.Tally(name='u233_abs');
u233_abs.scores = ['absorption'];
u233_abs.nuclides=['U233']; # take this to be the only fissile nuclide
u233_abs.filters = [cell_filter,efilter_capture]; # re-use the energy filter also



tallies = openmc.Tallies([flux, u238_capture, u233_abs]);
tallies.export_to_xml()

# %%
# establish settings for a criticality calculation
settings = openmc.Settings();
settings.run_mode = 'eigenvalue';
settings.particles = 20000;
settings.batches = 200;
settings.inactive = 50;

box = openmc.stats.Box(lower_left=(-r_o,-r_o,-h_fuel/2.),
                      upper_right = (r_o,r_o,h_fuel/2.),
                      only_fissionable=True);
src = openmc.Source(space=box);

settings.source = src;
settings.export_to_xml();

# %%
# run openmc
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.2
#           Git SHA1 | 37e74fb1e385478fdc25fdd0594b6f2cbb458d53
#          Date/Time | 2022-02-19 12:48:06
#     OpenMP Threads | 36
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U233 from /home/sblair/OMC_DATA/endfb71_hdf5/U233.h5
#  Reading U234 from /home/sblair/OMC_DATA/endfb71_hdf5/U234.h5
#  Reading U236 from /home/sblair/OMC_DATA/endfb71_hdf5/U236.h5
#  Reading U238 from /home/sblair/OMC_DATA/endfb71_hdf5/U238.h5
#  Reading O16 from /home/sblair/OMC_DATA/endfb71_hdf5/O16.h5
#  Reading Zr90 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr90.h5
#  Reading Zr91 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr91.h5
#  Reading Zr92 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr92.h5
#  Reading Zr94 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr94.h5
#  Reading Zr96 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr96.h5
#  Reading O17 from /home/sblair/OMC_DATA/endfb71_hdf5/O17.h5
#  Reading H2 from /home/sblair/OMC_DATA/endfb71_hdf5/H2.h5
#  Reading c_D_in_D2O from /home/sblair/OMC_DATA/endfb71_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 294.0 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for Zr90
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.97247
#         2/1    0.98868
#         3/1    1.02070
#         4/1    1.03417
#         5/1    1.07074
#         6/1    1.09301
#         7/1    1.11810
#         8/1    1.14123
#         9/1    1.16807
#        10/1    1.18627
#        11/1    1.20983
#        12/1    1.24202
#        13/1    1.23603
#        14/1    1.26116
#        15/1    1.24993
#        16/1    1.25239
#        17/1    1.24700
#        18/1    1.26590
#        19/1    1.24997
#        20/1    1.27314
#        21/1    1.25394
#        22/1    1.29704
#        23/1    1.27835
#        24/1    1.28279
#        25/1    1.25936
#        26/1    1.28611
#        27/1    1.25930
#        28/1    1.28404
#        29/1    1.27732
#        30/1    1.28756
#        31/1    1.25670
#        32/1    1.26076
#        33/1    1.28169
#        34/1    1.27884
#        35/1    1.25489
#        36/1    1.25933
#        37/1    1.29646
#        38/1    1.24208
#        39/1    1.27666
#        40/1    1.27392
#        41/1    1.28841
#        42/1    1.26983
#        43/1    1.27035
#        44/1    1.25879
#        45/1    1.27714
#        46/1    1.26956
#        47/1    1.27898
#        48/1    1.25849
#        49/1    1.28719
#        50/1    1.24863
#        51/1    1.26137
#        52/1    1.27294    1.26715 +/- 0.00579
#        53/1    1.26570    1.26667 +/- 0.00338
#        54/1    1.27977    1.26994 +/- 0.00405
#        55/1    1.27532    1.27102 +/- 0.00332
#        56/1    1.26724    1.27039 +/- 0.00278
#        57/1    1.26369    1.26943 +/- 0.00254
#        58/1    1.28765    1.27171 +/- 0.00317
#        59/1    1.27735    1.27234 +/- 0.00286
#        60/1    1.27563    1.27267 +/- 0.00258
#        61/1    1.27997    1.27333 +/- 0.00243
#        62/1    1.27629    1.27358 +/- 0.00223
#        63/1    1.26781    1.27313 +/- 0.00210
#        64/1    1.28662    1.27410 +/- 0.00217
#        65/1    1.27576    1.27421 +/- 0.00202
#        66/1    1.28764    1.27505 +/- 0.00207
#        67/1    1.28471    1.27561 +/- 0.00202
#        68/1    1.26910    1.27525 +/- 0.00194
#        69/1    1.28651    1.27584 +/- 0.00193
#        70/1    1.27811    1.27596 +/- 0.00184
#        71/1    1.26778    1.27557 +/- 0.00179
#        72/1    1.26911    1.27528 +/- 0.00173
#        73/1    1.28675    1.27577 +/- 0.00173
#        74/1    1.27494    1.27574 +/- 0.00165
#        75/1    1.29507    1.27651 +/- 0.00176
#        76/1    1.28317    1.27677 +/- 0.00171
#        77/1    1.28189    1.27696 +/- 0.00166
#        78/1    1.27421    1.27686 +/- 0.00160
#        79/1    1.27805    1.27690 +/- 0.00155
#        80/1    1.26393    1.27647 +/- 0.00156
#        81/1    1.28090    1.27661 +/- 0.00151
#        82/1    1.29059    1.27705 +/- 0.00153
#        83/1    1.26730    1.27675 +/- 0.00151
#        84/1    1.28814    1.27709 +/- 0.00150
#        85/1    1.27237    1.27695 +/- 0.00147
#        86/1    1.27554    1.27691 +/- 0.00142
#        87/1    1.28680    1.27718 +/- 0.00141
#        88/1    1.26366    1.27683 +/- 0.00142
#        89/1    1.27384    1.27675 +/- 0.00138
#        90/1    1.27730    1.27676 +/- 0.00135
#        91/1    1.27474    1.27671 +/- 0.00132
#        92/1    1.27941    1.27678 +/- 0.00129
#        93/1    1.28255    1.27691 +/- 0.00126
#        94/1    1.26231    1.27658 +/- 0.00128
#        95/1    1.28164    1.27669 +/- 0.00125
#        96/1    1.29580    1.27711 +/- 0.00130
#        97/1    1.28427    1.27726 +/- 0.00128
#        98/1    1.27171    1.27714 +/- 0.00126
#        99/1    1.27055    1.27701 +/- 0.00124
#       100/1    1.29122    1.27729 +/- 0.00124
#       101/1    1.27703    1.27729 +/- 0.00122
#       102/1    1.26930    1.27714 +/- 0.00121
#       103/1    1.26004    1.27681 +/- 0.00123
#       104/1    1.27485    1.27678 +/- 0.00120
#       105/1    1.26814    1.27662 +/- 0.00119
#       106/1    1.25477    1.27623 +/- 0.00123
#       107/1    1.26080    1.27596 +/- 0.00124
#       108/1    1.29466    1.27628 +/- 0.00126
#       109/1    1.29923    1.27667 +/- 0.00130
#       110/1    1.27996    1.27672 +/- 0.00128
#       111/1    1.25960    1.27644 +/- 0.00129
#       112/1    1.26989    1.27634 +/- 0.00127
#       113/1    1.24427    1.27583 +/- 0.00135
#       114/1    1.28492    1.27597 +/- 0.00134
#       115/1    1.25361    1.27563 +/- 0.00136
#       116/1    1.25550    1.27532 +/- 0.00138
#       117/1    1.27288    1.27529 +/- 0.00135
#       118/1    1.26866    1.27519 +/- 0.00134
#       119/1    1.26226    1.27500 +/- 0.00133
#       120/1    1.26608    1.27487 +/- 0.00132
#       121/1    1.29695    1.27518 +/- 0.00134
#       122/1    1.25925    1.27496 +/- 0.00134
#       123/1    1.28301    1.27507 +/- 0.00132
#       124/1    1.26507    1.27494 +/- 0.00131
#       125/1    1.28890    1.27512 +/- 0.00131
#       126/1    1.27955    1.27518 +/- 0.00129
#       127/1    1.25469    1.27492 +/- 0.00130
#       128/1    1.26816    1.27483 +/- 0.00129
#       129/1    1.24356    1.27443 +/- 0.00133
#       130/1    1.27063    1.27439 +/- 0.00132
#       131/1    1.25633    1.27416 +/- 0.00132
#       132/1    1.27514    1.27418 +/- 0.00130
#       133/1    1.26678    1.27409 +/- 0.00129
#       134/1    1.27281    1.27407 +/- 0.00127
#       135/1    1.28706    1.27422 +/- 0.00127
#       136/1    1.29442    1.27446 +/- 0.00128
#       137/1    1.25608    1.27425 +/- 0.00128
#       138/1    1.26320    1.27412 +/- 0.00127
#       139/1    1.27356    1.27412 +/- 0.00126
#       140/1    1.27033    1.27407 +/- 0.00124
#       141/1    1.26839    1.27401 +/- 0.00123
#       142/1    1.27321    1.27400 +/- 0.00122
#       143/1    1.27360    1.27400 +/- 0.00120
#       144/1    1.25267    1.27377 +/- 0.00121
#       145/1    1.29387    1.27398 +/- 0.00122
#       146/1    1.27842    1.27403 +/- 0.00121
#       147/1    1.27909    1.27408 +/- 0.00119
#       148/1    1.27301    1.27407 +/- 0.00118
#       149/1    1.28528    1.27418 +/- 0.00118
#       150/1    1.28702    1.27431 +/- 0.00117
#       151/1    1.27910    1.27436 +/- 0.00116
#       152/1    1.27742    1.27439 +/- 0.00115
#       153/1    1.24612    1.27411 +/- 0.00117
#       154/1    1.27975    1.27417 +/- 0.00116
#       155/1    1.28613    1.27428 +/- 0.00116
#       156/1    1.26459    1.27419 +/- 0.00115
#       157/1    1.27958    1.27424 +/- 0.00114
#       158/1    1.27164    1.27422 +/- 0.00113
#       159/1    1.28111    1.27428 +/- 0.00112
#       160/1    1.27126    1.27425 +/- 0.00111
#       161/1    1.25162    1.27405 +/- 0.00112
#       162/1    1.26868    1.27400 +/- 0.00111
#       163/1    1.28155    1.27407 +/- 0.00110
#       164/1    1.27944    1.27412 +/- 0.00109
#       165/1    1.25087    1.27391 +/- 0.00110
#       166/1    1.28918    1.27404 +/- 0.00110
#       167/1    1.26090    1.27393 +/- 0.00110
#       168/1    1.26647    1.27387 +/- 0.00109
#       169/1    1.27711    1.27390 +/- 0.00108
#       170/1    1.28645    1.27400 +/- 0.00108
#       171/1    1.27920    1.27404 +/- 0.00107
#       172/1    1.28177    1.27411 +/- 0.00106
#       173/1    1.27468    1.27411 +/- 0.00105
#       174/1    1.28503    1.27420 +/- 0.00105
#       175/1    1.30244    1.27443 +/- 0.00106
#       176/1    1.27761    1.27445 +/- 0.00106
#       177/1    1.28116    1.27450 +/- 0.00105
#       178/1    1.28847    1.27461 +/- 0.00105
#       179/1    1.25760    1.27448 +/- 0.00105
#       180/1    1.27435    1.27448 +/- 0.00104
#       181/1    1.27784    1.27451 +/- 0.00103
#       182/1    1.27678    1.27452 +/- 0.00102
#       183/1    1.27689    1.27454 +/- 0.00102
#       184/1    1.28782    1.27464 +/- 0.00101
#       185/1    1.26574    1.27457 +/- 0.00101
#       186/1    1.27253    1.27456 +/- 0.00100
#       187/1    1.28295    1.27462 +/- 0.00099
#       188/1    1.28128    1.27467 +/- 0.00099
#       189/1    1.27552    1.27467 +/- 0.00098
#       190/1    1.26436    1.27460 +/- 0.00098
#       191/1    1.25961    1.27449 +/- 0.00098
#       192/1    1.28437    1.27456 +/- 0.00097
#       193/1    1.26500    1.27450 +/- 0.00097
#       194/1    1.28202    1.27455 +/- 0.00096
#       195/1    1.26247    1.27447 +/- 0.00096
#       196/1    1.25314    1.27432 +/- 0.00096
#       197/1    1.26033    1.27423 +/- 0.00096
#       198/1    1.27592    1.27424 +/- 0.00095
#       199/1    1.28129    1.27428 +/- 0.00095
#       200/1    1.25612    1.27416 +/- 0.00095
#  Creating state point statepoint.200.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 7.6897e-01 seconds
#    Reading cross sections          = 7.5065e-01 seconds
#  Total time in simulation          = 1.1086e+02 seconds
#    Time in transport only          = 1.1031e+02 seconds
#    Time in inactive batches        = 2.2095e+01 seconds
#    Time in active batches          = 8.8761e+01 seconds
#    Time synchronizing fission bank = 3.2173e-01 seconds
#      Sampling source sites         = 2.8417e-01 seconds
#      SEND/RECV source sites        = 3.6852e-02 seconds
#    Time accumulating tallies       = 1.7998e-02 seconds
#    Time writing statepoints        = 9.5426e-03 seconds
#  Total time for finalization       = 2.1583e-03 seconds
#  Total time elapsed                = 1.1164e+02 seconds
#  Calculation Rate (inactive)       = 45259.9 particles/second
#  Calculation Rate (active)         = 33798.5 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.27456 +/- 0.00076
#  k-effective (Track-length)  = 1.27416 +/- 0.00095
#  k-effective (Absorption)    = 1.27433 +/- 0.00067
#  Combined k-effective        = 1.27443 +/- 0.00061
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
# get tally result and plot flux energy spectrum
sp = openmc.StatePoint('statepoint.200.h5')

flux_t = sp.get_tally(name='flux');
flux_df = flux_t.get_pandas_dataframe();
flux_vals = flux_df['mean'].to_numpy();

energy_x = 0.5*(energy_bins[0:-1]+energy_bins[1:])

plt.loglog(energy_x,flux_vals);
plt.grid();
plt.title('Baseline Neutron Spectrum in Fuel');
plt.xlabel('Energy [eV]');
plt.ylabel('flux [n/cm**2-s]');

# %%
# add neutron cross section data to provide context for the reaction tallys
OMC_DATA = "/home/sblair/OMC_DATA/endfb71_hdf5"  # work computer
#OMC_DATA = "/home/stu/OMC_DATA/endfb71_hdf5"    # personal computer

u238_path = OMC_DATA + "/U238.h5";
U238 = openmc.data.IncidentNeutron.from_hdf5(u238_path);
U238_capture = U238[102];

plt.rcParams['figure.figsize']=[12,8];
plt.loglog(energy_x,flux_vals,label='flux');
plt.loglog(U238_capture.xs['294K'].x,U238_capture.xs['294K'].y,label='U238 (n,\gamma)');
plt.grid();
plt.legend();
plt.xlabel('Energy [eV]')
plt.title('Flux and Capture Cross Section for U238');

# %%
u238_cap = sp.get_tally(name='u238_total_capture');
u238_cap_df = u238_cap.get_pandas_dataframe();

u233_abs = sp.get_tally(name='u233_abs');
u233_abs_df = u233_abs.get_pandas_dataframe();

# %%
u238_cap_vals = u238_cap_df['mean'].to_numpy();
u233_abs_vals = u233_abs_df['mean'].to_numpy();
tot_u238_capture = u238_cap_vals.sum();
tot_u233_abs = u233_abs_vals.sum(); 

print('Total U233 absorptions per source particle: %5.3f.' % tot_u233_abs);
print('U233 thermal absorptions: %5.3f ' % u233_abs_vals[0]);
print('U233 resonance absorptions: %5.3f' % u233_abs_vals[1]);
print('U233 high-energy absorptions: %5.3f' % u233_abs_vals[2]);

print('Total U238 captures per source particle: %5.3f' % tot_u238_capture);
print('U238 thermal captures: %5.3f ' % u238_cap_vals[0]);
print('U238 resonance captures: %5.3f ' % u238_cap_vals[1]);
print('U238 high-energy captures: %5.3f' % u238_cap_vals[2]);
# Out:
# Total U233 absorptions per source particle: 0.520.
# U233 thermal absorptions: 0.244
# U233 resonance absorptions: 0.233
# U233 high-energy absorptions: 0.044
# Total U238 captures per source particle: 0.415
# U238 thermal captures: 0.027
# U238 resonance captures: 0.319
# U238 high-energy captures: 0.069

# %%
print('Conversion ratio of U238 from high-energy neutrons: %5.3f ' % (u238_cap_vals[2]/tot_u233_abs));
print('Conversion ratio of U238 from neutrons in resonance energy region: %5.3f' % (u238_cap_vals[1]/tot_u233_abs));
print('Conversion ratio of U238 from neutrons in thermal energy region: %5.3f' % (u238_cap_vals[0]/tot_u233_abs));
print('Total initial conversion ratio: %5.3f' % (tot_u238_capture/tot_u233_abs));
# Out:
# Conversion ratio of U238 from high-energy neutrons: 0.133
# Conversion ratio of U238 from neutrons in resonance energy region: 0.613
# Conversion ratio of U238 from neutrons in thermal energy region: 0.052
# Total initial conversion ratio: 0.797
