# %% [markdown]
# # PHWR U233
# This notebook is intended to compute the neutron energy spectrum and conversion ratio for a PHWR similar to the baseline example, but fueled instead with U-233

# %%
import openmc
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
# define the fuel material
fuel = openmc.Material(name='fuel');
fuel.set_density('g/cm3',10.45);
# use atom fractions for 4 a/o U-233.
# estimate based on 4 a/o U-235 materials.xml file
fuel.add_nuclide('U233',0.040491);
fuel.add_nuclide('U234',0.000362);
fuel.add_nuclide('U236',0.0001855);
fuel.add_nuclide('U238',0.9589619);
fuel.add_nuclide('O16',2.0);

# ignore the gap gas (negligible impact on neutron energy)

# just use elemental Zirconium for clad.
clad = openmc.Material(name='clad');
clad.add_element('Zr',1);
clad.set_density('g/cm3',6.0);

mod = openmc.Material(name='moderator');
mod.add_element('O',1);
mod.add_nuclide('H2',2);
mod.set_density('g/cm3',0.712); #high temperature density
mod.add_s_alpha_beta('c_D_in_D2O');

# create Materials object and export to xml
materials = openmc.Materials([fuel,clad,mod]);
materials.export_to_xml();

# %%
# define the pin cell geometry
h_core = 500.;
h_fuel = 426.7;

r_o = 0.819/2.; #cm, fuel outer radius
r_ci = r_o +  0.008255; # clad inner radius 
r_co = 0.95/2.; # clad outer radius

#P_D = 1.326;
P_D = 1.4;

pitch = P_D*(2*r_co);

#fuel cylinder
fuel_cyl = openmc.model.RightCircularCylinder([0.,0.,-h_fuel/2.],
                                             h_fuel,r_o);
fuel.volume = np.pi*(r_o**2)*h_fuel;

# clad inner cylinder
cladi_cyl = openmc.model.RightCircularCylinder([0.,0.,-h_fuel/2.],
                                              h_fuel,r_ci);
# clad outer cylinder
clado_cyl = openmc.model.RightCircularCylinder([0.,0.,-h_fuel/2.],
                                              h_fuel,r_co);
# pin cell container
core_cell = openmc.model.RectangularParallelepiped(-pitch/2.,pitch/2.,
                                                  -pitch/2.,pitch/2.,
                                                  -h_core/2.,h_core/2.,
                                                  boundary_type='reflective');


fuel_cell = openmc.Cell();
fuel_cell.region = -fuel_cyl
fuel_cell.fill = fuel;
fuel_cell.temperature = 1000. + 273.;

gap_cell = openmc.Cell();
gap_cell.region = +fuel_cyl & -cladi_cyl;
gap_cell.fill = None; # same as "void"

clad_cell = openmc.Cell();
clad_cell.region = +cladi_cyl & -clado_cyl;
clad_cell.fill = clad;
clad_cell.temperature = 500. + 273.;


mod_cell = openmc.Cell();
mod_cell.region = +clado_cyl & -core_cell;
mod_cell.fill = mod;
mod_cell.temperature = 300. + 273.;

root_univ = openmc.Universe();
root_univ.add_cells([fuel_cell,gap_cell,clad_cell,mod_cell]);

geometry = openmc.Geometry();
geometry.root_universe = root_univ;

geometry.export_to_xml();

# %%
colors = {}
colors[fuel]='yellow'
colors[mod] = 'blue'
colors[clad] = 'grey'

root_univ.plot(width=(pitch,pitch),pixels=[400,400],
               color_by='material',colors=colors);

# %%
# create tally to determine flux energy spectrum in the fuel

cell_filter = openmc.CellFilter(fuel_cell);

# set up energy bins
N = 1001;
energy_bins = np.logspace(-3,7,num=N);
energy_filter = openmc.EnergyFilter(values=energy_bins);

# establish flux tally
flux = openmc.Tally(name='flux');
flux.scores = ['flux'];
flux.filters = [cell_filter,energy_filter];

# create a tally to estimate conversion ratio
# use cell_filter as before
u238_capture = openmc.Tally(name='u238_total_capture');
u238_capture.scores = ['(n,gamma)'];
u238_capture.nuclides=['U238']; #take this to be the only fertile nuclide
efilter_values = [0.0, 1.0, 3.0e4, 14.0e6]; # OpenMC energy units are eV
efilter_capture = openmc.EnergyFilter(values=efilter_values);
u238_capture.filters = [cell_filter, efilter_capture];

u233_abs = openmc.Tally(name='u233_abs');
u233_abs.scores = ['absorption'];
u233_abs.nuclides=['U233']; # take this to be the only fissile nuclide
u233_abs.filters = [cell_filter,efilter_capture]; # re-use the energy filter also



tallies = openmc.Tallies([flux, u238_capture, u233_abs]);
tallies.export_to_xml()

# %%
# establish settings for a criticality calculation
settings = openmc.Settings();
settings.run_mode = 'eigenvalue';
settings.particles = 20000;
settings.batches = 200;
settings.inactive = 50;

box = openmc.stats.Box(lower_left=(-r_o,-r_o,-h_fuel/2.),
                      upper_right = (r_o,r_o,h_fuel/2.),
                      only_fissionable=True);
src = openmc.Source(space=box);

settings.source = src;

settings.temperature['method']='interpolation';
settings.export_to_xml();

# %%
# run openmc
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.2
#           Git SHA1 | 37e74fb1e385478fdc25fdd0594b6f2cbb458d53
#          Date/Time | 2022-02-22 12:26:02
#     OpenMP Threads | 36
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U233 from /home/sblair/OMC_DATA/endfb71_hdf5/U233.h5
#  Reading U234 from /home/sblair/OMC_DATA/endfb71_hdf5/U234.h5
#  Reading U236 from /home/sblair/OMC_DATA/endfb71_hdf5/U236.h5
#  Reading U238 from /home/sblair/OMC_DATA/endfb71_hdf5/U238.h5
#  Reading O16 from /home/sblair/OMC_DATA/endfb71_hdf5/O16.h5
#  Reading Zr90 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr90.h5
#  Reading Zr91 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr91.h5
#  Reading Zr92 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr92.h5
#  Reading Zr94 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr94.h5
#  Reading Zr96 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr96.h5
#  Reading O17 from /home/sblair/OMC_DATA/endfb71_hdf5/O17.h5
#  Reading H2 from /home/sblair/OMC_DATA/endfb71_hdf5/H2.h5
#  Reading c_D_in_D2O from /home/sblair/OMC_DATA/endfb71_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 2500.0 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for Zr90
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.01361
#         2/1    1.01436
#         3/1    1.04953
#         4/1    1.05412
#         5/1    1.10174
#         6/1    1.10324
#         7/1    1.09155
#         8/1    1.14483
#         9/1    1.13331
#        10/1    1.16861
#        11/1    1.17661
#        12/1    1.19367
#        13/1    1.17909
#        14/1    1.20157
#        15/1    1.22068
#        16/1    1.24521
#        17/1    1.23458
#        18/1    1.24585
#        19/1    1.24121
#        20/1    1.22447
#        21/1    1.23837
#        22/1    1.23162
#        23/1    1.24130
#        24/1    1.22298
#        25/1    1.21117
#        26/1    1.25574
#        27/1    1.25784
#        28/1    1.24731
#        29/1    1.23878
#        30/1    1.24225
#        31/1    1.24787
#        32/1    1.24201
#        33/1    1.24378
#        34/1    1.25132
#        35/1    1.25784
#        36/1    1.23480
#        37/1    1.24251
#        38/1    1.23435
#        39/1    1.25156
#        40/1    1.25142
#        41/1    1.24435
#        42/1    1.22784
#        43/1    1.25495
#        44/1    1.24007
#        45/1    1.23738
#        46/1    1.23109
#        47/1    1.23905
#        48/1    1.24914
#        49/1    1.24525
#        50/1    1.23403
#        51/1    1.25558
#        52/1    1.24839    1.25199 +/- 0.00359
#        53/1    1.24093    1.24830 +/- 0.00423
#        54/1    1.25092    1.24896 +/- 0.00306
#        55/1    1.24951    1.24907 +/- 0.00237
#        56/1    1.26437    1.25162 +/- 0.00320
#        57/1    1.21608    1.24654 +/- 0.00575
#        58/1    1.25247    1.24728 +/- 0.00504
#        59/1    1.23695    1.24613 +/- 0.00459
#        60/1    1.26230    1.24775 +/- 0.00441
#        61/1    1.23632    1.24671 +/- 0.00412
#        62/1    1.24384    1.24647 +/- 0.00377
#        63/1    1.25377    1.24703 +/- 0.00351
#        64/1    1.25276    1.24744 +/- 0.00328
#        65/1    1.25448    1.24791 +/- 0.00309
#        66/1    1.24534    1.24775 +/- 0.00289
#        67/1    1.24495    1.24759 +/- 0.00272
#        68/1    1.24382    1.24738 +/- 0.00258
#        69/1    1.25636    1.24785 +/- 0.00248
#        70/1    1.21707    1.24631 +/- 0.00281
#        71/1    1.25111    1.24654 +/- 0.00269
#        72/1    1.22592    1.24560 +/- 0.00273
#        73/1    1.24247    1.24546 +/- 0.00261
#        74/1    1.25474    1.24585 +/- 0.00253
#        75/1    1.25670    1.24629 +/- 0.00246
#        76/1    1.25059    1.24645 +/- 0.00237
#        77/1    1.25096    1.24662 +/- 0.00229
#        78/1    1.25611    1.24696 +/- 0.00223
#        79/1    1.25005    1.24706 +/- 0.00216
#        80/1    1.23206    1.24656 +/- 0.00214
#        81/1    1.24798    1.24661 +/- 0.00207
#        82/1    1.25406    1.24684 +/- 0.00202
#        83/1    1.24800    1.24688 +/- 0.00196
#        84/1    1.23913    1.24665 +/- 0.00191
#        85/1    1.23630    1.24635 +/- 0.00188
#        86/1    1.24613    1.24635 +/- 0.00183
#        87/1    1.22872    1.24587 +/- 0.00184
#        88/1    1.24262    1.24579 +/- 0.00179
#        89/1    1.23419    1.24549 +/- 0.00177
#        90/1    1.25135    1.24563 +/- 0.00173
#        91/1    1.21544    1.24490 +/- 0.00184
#        92/1    1.25506    1.24514 +/- 0.00182
#        93/1    1.22736    1.24473 +/- 0.00182
#        94/1    1.24791    1.24480 +/- 0.00178
#        95/1    1.26092    1.24516 +/- 0.00178
#        96/1    1.23988    1.24504 +/- 0.00174
#        97/1    1.25224    1.24520 +/- 0.00171
#        98/1    1.25426    1.24538 +/- 0.00169
#        99/1    1.23797    1.24523 +/- 0.00166
#       100/1    1.22148    1.24476 +/- 0.00169
#       101/1    1.24410    1.24474 +/- 0.00166
#       102/1    1.23981    1.24465 +/- 0.00163
#       103/1    1.24381    1.24463 +/- 0.00160
#       104/1    1.23953    1.24454 +/- 0.00157
#       105/1    1.25364    1.24471 +/- 0.00155
#       106/1    1.25894    1.24496 +/- 0.00154
#       107/1    1.23118    1.24472 +/- 0.00154
#       108/1    1.23774    1.24460 +/- 0.00151
#       109/1    1.22197    1.24421 +/- 0.00154
#       110/1    1.27119    1.24466 +/- 0.00158
#       111/1    1.23905    1.24457 +/- 0.00155
#       112/1    1.23243    1.24438 +/- 0.00154
#       113/1    1.26349    1.24468 +/- 0.00155
#       114/1    1.25414    1.24483 +/- 0.00153
#       115/1    1.25407    1.24497 +/- 0.00151
#       116/1    1.23114    1.24476 +/- 0.00150
#       117/1    1.23685    1.24464 +/- 0.00149
#       118/1    1.24221    1.24461 +/- 0.00146
#       119/1    1.22917    1.24438 +/- 0.00146
#       120/1    1.26132    1.24462 +/- 0.00146
#       121/1    1.25458    1.24476 +/- 0.00145
#       122/1    1.24237    1.24473 +/- 0.00143
#       123/1    1.26747    1.24504 +/- 0.00144
#       124/1    1.25942    1.24524 +/- 0.00143
#       125/1    1.25320    1.24534 +/- 0.00142
#       126/1    1.25628    1.24549 +/- 0.00141
#       127/1    1.25765    1.24564 +/- 0.00140
#       128/1    1.24516    1.24564 +/- 0.00138
#       129/1    1.23975    1.24556 +/- 0.00136
#       130/1    1.25327    1.24566 +/- 0.00135
#       131/1    1.23800    1.24557 +/- 0.00134
#       132/1    1.26557    1.24581 +/- 0.00134
#       133/1    1.25604    1.24593 +/- 0.00133
#       134/1    1.25456    1.24604 +/- 0.00132
#       135/1    1.24760    1.24605 +/- 0.00130
#       136/1    1.25127    1.24611 +/- 0.00129
#       137/1    1.22576    1.24588 +/- 0.00130
#       138/1    1.23756    1.24579 +/- 0.00129
#       139/1    1.24800    1.24581 +/- 0.00127
#       140/1    1.26043    1.24597 +/- 0.00127
#       141/1    1.26255    1.24616 +/- 0.00127
#       142/1    1.23466    1.24603 +/- 0.00126
#       143/1    1.23351    1.24590 +/- 0.00125
#       144/1    1.24151    1.24585 +/- 0.00124
#       145/1    1.25786    1.24598 +/- 0.00123
#       146/1    1.25375    1.24606 +/- 0.00122
#       147/1    1.24716    1.24607 +/- 0.00121
#       148/1    1.26117    1.24622 +/- 0.00121
#       149/1    1.25371    1.24630 +/- 0.00120
#       150/1    1.24327    1.24627 +/- 0.00119
#       151/1    1.25652    1.24637 +/- 0.00118
#       152/1    1.26242    1.24653 +/- 0.00118
#       153/1    1.23920    1.24646 +/- 0.00117
#       154/1    1.25956    1.24658 +/- 0.00116
#       155/1    1.23675    1.24649 +/- 0.00116
#       156/1    1.26193    1.24663 +/- 0.00116
#       157/1    1.24558    1.24662 +/- 0.00114
#       158/1    1.23824    1.24655 +/- 0.00114
#       159/1    1.24667    1.24655 +/- 0.00113
#       160/1    1.25686    1.24664 +/- 0.00112
#       161/1    1.27158    1.24687 +/- 0.00113
#       162/1    1.25270    1.24692 +/- 0.00112
#       163/1    1.24605    1.24691 +/- 0.00111
#       164/1    1.24104    1.24686 +/- 0.00110
#       165/1    1.26571    1.24702 +/- 0.00111
#       166/1    1.22842    1.24686 +/- 0.00111
#       167/1    1.25613    1.24694 +/- 0.00110
#       168/1    1.26011    1.24705 +/- 0.00110
#       169/1    1.25239    1.24710 +/- 0.00109
#       170/1    1.26384    1.24724 +/- 0.00109
#       171/1    1.21518    1.24697 +/- 0.00111
#       172/1    1.22563    1.24680 +/- 0.00112
#       173/1    1.25229    1.24684 +/- 0.00111
#       174/1    1.24400    1.24682 +/- 0.00110
#       175/1    1.24525    1.24681 +/- 0.00109
#       176/1    1.24794    1.24682 +/- 0.00108
#       177/1    1.24669    1.24681 +/- 0.00107
#       178/1    1.24228    1.24678 +/- 0.00107
#       179/1    1.25215    1.24682 +/- 0.00106
#       180/1    1.25415    1.24688 +/- 0.00105
#       181/1    1.22957    1.24674 +/- 0.00105
#       182/1    1.22273    1.24656 +/- 0.00106
#       183/1    1.25663    1.24664 +/- 0.00106
#       184/1    1.26630    1.24679 +/- 0.00106
#       185/1    1.24054    1.24674 +/- 0.00105
#       186/1    1.25294    1.24678 +/- 0.00104
#       187/1    1.24209    1.24675 +/- 0.00104
#       188/1    1.23819    1.24669 +/- 0.00103
#       189/1    1.25692    1.24676 +/- 0.00103
#       190/1    1.23340    1.24667 +/- 0.00102
#       191/1    1.23844    1.24661 +/- 0.00102
#       192/1    1.26143    1.24671 +/- 0.00102
#       193/1    1.25338    1.24676 +/- 0.00101
#       194/1    1.20786    1.24649 +/- 0.00104
#       195/1    1.24337    1.24647 +/- 0.00103
#       196/1    1.24981    1.24649 +/- 0.00103
#       197/1    1.25628    1.24656 +/- 0.00102
#       198/1    1.22052    1.24638 +/- 0.00103
#       199/1    1.26453    1.24650 +/- 0.00103
#       200/1    1.22303    1.24635 +/- 0.00103
#  Creating state point statepoint.200.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.1509e-01 seconds
#    Reading cross sections          = 8.9574e-01 seconds
#  Total time in simulation          = 7.5158e+01 seconds
#    Time in transport only          = 7.4512e+01 seconds
#    Time in inactive batches        = 1.5304e+01 seconds
#    Time in active batches          = 5.9854e+01 seconds
#    Time synchronizing fission bank = 3.2254e-01 seconds
#      Sampling source sites         = 2.8500e-01 seconds
#      SEND/RECV source sites        = 3.6844e-02 seconds
#    Time accumulating tallies       = 1.1536e-01 seconds
#    Time writing statepoints        = 6.9239e-03 seconds
#  Total time for finalization       = 1.5000e-03 seconds
#  Total time elapsed                = 7.6089e+01 seconds
#  Calculation Rate (inactive)       = 65344.0 particles/second
#  Calculation Rate (active)         = 50121.7 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.24658 +/- 0.00091
#  k-effective (Track-length)  = 1.24635 +/- 0.00103
#  k-effective (Absorption)    = 1.24500 +/- 0.00069
#  Combined k-effective        = 1.24550 +/- 0.00064
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
# get tally result and plot flux energy spectrum
sp = openmc.StatePoint('statepoint.200.h5')

flux_t = sp.get_tally(name='flux');
flux_df = flux_t.get_pandas_dataframe();
flux_vals = flux_df['mean'].to_numpy();

energy_x = 0.5*(energy_bins[0:-1]+energy_bins[1:])

plt.loglog(energy_x,flux_vals);
plt.grid();
plt.title('Baseline Neutron Spectrum in Fuel');
plt.xlabel('Energy [eV]');
plt.ylabel('flux [n/cm**2-s]');

# %%
# add neutron cross section data to provide context for the reaction tallys
OMC_DATA = "/home/sblair/OMC_DATA/endfb71_hdf5"  # work computer
#OMC_DATA = "/home/stu/OMC_DATA/endfb71_hdf5"    # personal computer

u238_path = OMC_DATA + "/U238.h5";
U238 = openmc.data.IncidentNeutron.from_hdf5(u238_path);
U238_capture = U238[102];

plt.rcParams['figure.figsize']=[12,8];
plt.loglog(energy_x,flux_vals,label='flux');
plt.loglog(U238_capture.xs['294K'].x,U238_capture.xs['294K'].y,label='U238 (n,\gamma)');
plt.grid();
plt.legend();
plt.xlabel('Energy [eV]')
plt.title('Flux and Capture Cross Section for U238');

# %%
u238_cap = sp.get_tally(name='u238_total_capture');
u238_cap_df = u238_cap.get_pandas_dataframe();

u233_abs = sp.get_tally(name='u233_abs');
u233_abs_df = u233_abs.get_pandas_dataframe();

# %%
u238_cap_vals = u238_cap_df['mean'].to_numpy();
u233_abs_vals = u233_abs_df['mean'].to_numpy();
tot_u238_capture = u238_cap_vals.sum();
tot_u233_abs = u233_abs_vals.sum(); 

print('Total U233 absorptions per source particle: %5.3f.' % tot_u233_abs);
print('U233 thermal absorptions: %5.3f ' % u233_abs_vals[0]);
print('U233 resonance absorptions: %5.3f' % u233_abs_vals[1]);
print('U233 high-energy absorptions: %5.3f' % u233_abs_vals[2]);

print('Total U238 captures per source particle: %5.3f' % tot_u238_capture);
print('U238 thermal captures: %5.3f ' % u238_cap_vals[0]);
print('U238 resonance captures: %5.3f ' % u238_cap_vals[1]);
print('U238 high-energy captures: %5.3f' % u238_cap_vals[2]);
# Out:
# Total U233 absorptions per source particle: 0.528.
# U233 thermal absorptions: 0.238
# U233 resonance absorptions: 0.265
# U233 high-energy absorptions: 0.025
# Total U238 captures per source particle: 0.424
# U238 thermal captures: 0.026
# U238 resonance captures: 0.359
# U238 high-energy captures: 0.039

# %%
print('Conversion ratio of U238 from high-energy neutrons: %5.3f ' % (u238_cap_vals[2]/tot_u233_abs));
print('Conversion ratio of U238 from neutrons in resonance energy region: %5.3f' % (u238_cap_vals[1]/tot_u233_abs));
print('Conversion ratio of U238 from neutrons in thermal energy region: %5.3f' % (u238_cap_vals[0]/tot_u233_abs));
print('Total initial conversion ratio: %5.3f' % (tot_u238_capture/tot_u233_abs));
# Out:
# Conversion ratio of U238 from high-energy neutrons: 0.073
# Conversion ratio of U238 from neutrons in resonance energy region: 0.680
# Conversion ratio of U238 from neutrons in thermal energy region: 0.049
# Total initial conversion ratio: 0.803
