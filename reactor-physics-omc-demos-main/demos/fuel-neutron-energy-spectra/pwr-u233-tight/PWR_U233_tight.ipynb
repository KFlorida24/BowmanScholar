# %% [markdown]
# # PWR U233
# This notebook is intended to compute the neutron energy spectrum and conversion ratio for a PWR similar to the baseline example, but fueled instead with U-233

# %%
import openmc
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
# define the fuel material
fuel = openmc.Material(name='fuel');
fuel.set_density('g/cm3',10.45);
# use atom fractions for 4 a/o U-233.
# estimate based on 4 a/o U-235 materials.xml file
fuel.add_nuclide('U233',0.040491);
fuel.add_nuclide('U234',0.000362);
fuel.add_nuclide('U236',0.0001855);
fuel.add_nuclide('U238',0.9589619);
fuel.add_nuclide('O16',2.0);

# ignore the gap gas (negligible impact on neutron energy)

# just use elemental Zirconium for clad.
clad = openmc.Material(name='clad');
clad.add_element('Zr',1);
clad.set_density('g/cm3',6.0);

mod = openmc.Material(name='moderator');
mod.add_element('O',1);
mod.add_element('H',2);
mod.set_density('g/cm3',0.712); #high temperature density
mod.add_s_alpha_beta('c_H_in_H2O');

# create Materials object and export to xml
materials = openmc.Materials([fuel,clad,mod]);
materials.export_to_xml();

# %%
# define the pin cell geometry
h_core = 500.;
h_fuel = 426.7;

r_o = 0.819/2.; #cm, fuel outer radius
r_ci = r_o +  0.008255; # clad inner radius 
r_co = 0.95/2.; # clad outer radius

P_D = 1.1;

pitch = P_D*(2*r_co);

#fuel cylinder
fuel_cyl = openmc.model.RightCircularCylinder([0.,0.,-h_fuel/2.],
                                             h_fuel,r_o);
fuel.volume = np.pi*(r_o**2)*h_fuel;

# clad inner cylinder
cladi_cyl = openmc.model.RightCircularCylinder([0.,0.,-h_fuel/2.],
                                              h_fuel,r_ci);
# clad outer cylinder
clado_cyl = openmc.model.RightCircularCylinder([0.,0.,-h_fuel/2.],
                                              h_fuel,r_co);
# pin cell container
core_cell = openmc.model.RectangularParallelepiped(-pitch/2.,pitch/2.,
                                                  -pitch/2.,pitch/2.,
                                                  -h_core/2.,h_core/2.,
                                                  boundary_type='reflective');


fuel_cell = openmc.Cell();
fuel_cell.region = -fuel_cyl
fuel_cell.fill = fuel;

gap_cell = openmc.Cell();
gap_cell.region = +fuel_cyl & -cladi_cyl;
gap_cell.fill = None; # same as "void"

clad_cell = openmc.Cell();
clad_cell.region = +cladi_cyl & -clado_cyl;
clad_cell.fill = clad;

mod_cell = openmc.Cell();
mod_cell.region = +clado_cyl & -core_cell;
mod_cell.fill = mod;

root_univ = openmc.Universe();
root_univ.add_cells([fuel_cell,gap_cell,clad_cell,mod_cell]);

geometry = openmc.Geometry();
geometry.root_universe = root_univ;

geometry.export_to_xml();

# %%
colors = {}
colors[fuel]='yellow'
colors[mod] = 'blue'
colors[clad] = 'grey'

root_univ.plot(width=(pitch,pitch),pixels=[400,400],
               color_by='material',colors=colors);

# %%
# create tally to determine flux energy spectrum in the fuel

cell_filter = openmc.CellFilter(fuel_cell);

# set up energy bins
N = 1001;
energy_bins = np.logspace(-3,7,num=N);
energy_filter = openmc.EnergyFilter(values=energy_bins);

# establish flux tally
flux = openmc.Tally(name='flux');
flux.scores = ['flux'];
flux.filters = [cell_filter,energy_filter];

# create a tally to estimate conversion ratio
# use cell_filter as before
u238_capture = openmc.Tally(name='u238_total_capture');
u238_capture.scores = ['(n,gamma)'];
u238_capture.nuclides=['U238']; #take this to be the only fertile nuclide
efilter_values = [0.0, 1.0, 3.0e4, 14.0e6]; # OpenMC energy units are eV
efilter_capture = openmc.EnergyFilter(values=efilter_values);
u238_capture.filters = [cell_filter, efilter_capture];

u233_abs = openmc.Tally(name='u233_abs');
u233_abs.scores = ['absorption'];
u233_abs.nuclides=['U233']; # take this to be the only fissile nuclide
u233_abs.filters = [cell_filter,efilter_capture]; # re-use the energy filter also



tallies = openmc.Tallies([flux, u238_capture, u233_abs]);
tallies.export_to_xml()

# %%
# establish settings for a criticality calculation
settings = openmc.Settings();
settings.run_mode = 'eigenvalue';
settings.particles = 20000;
settings.batches = 200;
settings.inactive = 50;

box = openmc.stats.Box(lower_left=(-r_o,-r_o,-h_fuel/2.),
                      upper_right = (r_o,r_o,h_fuel/2.),
                      only_fissionable=True);
src = openmc.Source(space=box);

settings.source = src;
settings.export_to_xml();

# %%
# run openmc
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.2
#           Git SHA1 | 37e74fb1e385478fdc25fdd0594b6f2cbb458d53
#          Date/Time | 2022-02-19 12:16:11
#     OpenMP Threads | 36
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U233 from /home/sblair/OMC_DATA/endfb71_hdf5/U233.h5
#  Reading U234 from /home/sblair/OMC_DATA/endfb71_hdf5/U234.h5
#  Reading U236 from /home/sblair/OMC_DATA/endfb71_hdf5/U236.h5
#  Reading U238 from /home/sblair/OMC_DATA/endfb71_hdf5/U238.h5
#  Reading O16 from /home/sblair/OMC_DATA/endfb71_hdf5/O16.h5
#  Reading Zr90 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr90.h5
#  Reading Zr91 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr91.h5
#  Reading Zr92 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr92.h5
#  Reading Zr94 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr94.h5
#  Reading Zr96 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr96.h5
#  Reading O17 from /home/sblair/OMC_DATA/endfb71_hdf5/O17.h5
#  Reading H1 from /home/sblair/OMC_DATA/endfb71_hdf5/H1.h5
#  Reading H2 from /home/sblair/OMC_DATA/endfb71_hdf5/H2.h5
#  Reading c_H_in_H2O from /home/sblair/OMC_DATA/endfb71_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 294.0 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for Zr90
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.40001
#         2/1    1.42118
#         3/1    1.40494
#         4/1    1.40105
#         5/1    1.41436
#         6/1    1.39319
#         7/1    1.40873
#         8/1    1.40558
#         9/1    1.41095
#        10/1    1.40441
#        11/1    1.42216
#        12/1    1.39938
#        13/1    1.41607
#        14/1    1.42356
#        15/1    1.43032
#        16/1    1.41390
#        17/1    1.41743
#        18/1    1.42740
#        19/1    1.41270
#        20/1    1.40932
#        21/1    1.44761
#        22/1    1.40603
#        23/1    1.40437
#        24/1    1.41776
#        25/1    1.42147
#        26/1    1.40261
#        27/1    1.42391
#        28/1    1.42533
#        29/1    1.42899
#        30/1    1.42661
#        31/1    1.40912
#        32/1    1.41883
#        33/1    1.42654
#        34/1    1.42493
#        35/1    1.41534
#        36/1    1.43110
#        37/1    1.41454
#        38/1    1.39961
#        39/1    1.43097
#        40/1    1.40712
#        41/1    1.40762
#        42/1    1.42638
#        43/1    1.42594
#        44/1    1.41722
#        45/1    1.44016
#        46/1    1.42783
#        47/1    1.40946
#        48/1    1.41653
#        49/1    1.42121
#        50/1    1.41603
#        51/1    1.40047
#        52/1    1.41430    1.40739 +/- 0.00691
#        53/1    1.41646    1.41041 +/- 0.00501
#        54/1    1.43621    1.41686 +/- 0.00736
#        55/1    1.38787    1.41106 +/- 0.00813
#        56/1    1.42773    1.41384 +/- 0.00720
#        57/1    1.41367    1.41381 +/- 0.00608
#        58/1    1.41850    1.41440 +/- 0.00530
#        59/1    1.44686    1.41801 +/- 0.00590
#        60/1    1.43753    1.41996 +/- 0.00563
#        61/1    1.42454    1.42038 +/- 0.00511
#        62/1    1.44384    1.42233 +/- 0.00506
#        63/1    1.40448    1.42096 +/- 0.00485
#        64/1    1.41259    1.42036 +/- 0.00453
#        65/1    1.42875    1.42092 +/- 0.00425
#        66/1    1.43057    1.42152 +/- 0.00403
#        67/1    1.42639    1.42181 +/- 0.00379
#        68/1    1.40470    1.42086 +/- 0.00370
#        69/1    1.41097    1.42034 +/- 0.00354
#        70/1    1.40856    1.41975 +/- 0.00341
#        71/1    1.40139    1.41888 +/- 0.00336
#        72/1    1.41311    1.41861 +/- 0.00321
#        73/1    1.41994    1.41867 +/- 0.00307
#        74/1    1.42103    1.41877 +/- 0.00294
#        75/1    1.41427    1.41859 +/- 0.00283
#        76/1    1.43449    1.41920 +/- 0.00278
#        77/1    1.42741    1.41951 +/- 0.00270
#        78/1    1.42173    1.41958 +/- 0.00260
#        79/1    1.41057    1.41927 +/- 0.00253
#        80/1    1.42098    1.41933 +/- 0.00244
#        81/1    1.42639    1.41956 +/- 0.00237
#        82/1    1.42551    1.41974 +/- 0.00230
#        83/1    1.39243    1.41892 +/- 0.00238
#        84/1    1.44019    1.41954 +/- 0.00239
#        85/1    1.41401    1.41938 +/- 0.00233
#        86/1    1.41799    1.41935 +/- 0.00226
#        87/1    1.41499    1.41923 +/- 0.00221
#        88/1    1.41931    1.41923 +/- 0.00215
#        89/1    1.41876    1.41922 +/- 0.00209
#        90/1    1.41336    1.41907 +/- 0.00204
#        91/1    1.42854    1.41930 +/- 0.00201
#        92/1    1.42224    1.41937 +/- 0.00196
#        93/1    1.40577    1.41906 +/- 0.00194
#        94/1    1.42662    1.41923 +/- 0.00190
#        95/1    1.42104    1.41927 +/- 0.00186
#        96/1    1.40789    1.41902 +/- 0.00184
#        97/1    1.40587    1.41874 +/- 0.00182
#        98/1    1.40735    1.41850 +/- 0.00180
#        99/1    1.40981    1.41833 +/- 0.00177
#       100/1    1.42425    1.41844 +/- 0.00174
#       101/1    1.41282    1.41833 +/- 0.00170
#       102/1    1.42264    1.41842 +/- 0.00167
#       103/1    1.42489    1.41854 +/- 0.00165
#       104/1    1.41831    1.41853 +/- 0.00162
#       105/1    1.40074    1.41821 +/- 0.00162
#       106/1    1.41929    1.41823 +/- 0.00159
#       107/1    1.43912    1.41860 +/- 0.00160
#       108/1    1.45037    1.41914 +/- 0.00167
#       109/1    1.40624    1.41893 +/- 0.00165
#       110/1    1.42345    1.41900 +/- 0.00163
#       111/1    1.42335    1.41907 +/- 0.00160
#       112/1    1.41084    1.41894 +/- 0.00158
#       113/1    1.41756    1.41892 +/- 0.00156
#       114/1    1.39911    1.41861 +/- 0.00156
#       115/1    1.42821    1.41876 +/- 0.00155
#       116/1    1.43149    1.41895 +/- 0.00154
#       117/1    1.39886    1.41865 +/- 0.00154
#       118/1    1.41345    1.41857 +/- 0.00152
#       119/1    1.44349    1.41893 +/- 0.00154
#       120/1    1.40662    1.41876 +/- 0.00153
#       121/1    1.41682    1.41873 +/- 0.00151
#       122/1    1.41855    1.41873 +/- 0.00149
#       123/1    1.41744    1.41871 +/- 0.00147
#       124/1    1.44305    1.41904 +/- 0.00148
#       125/1    1.41815    1.41903 +/- 0.00146
#       126/1    1.41573    1.41898 +/- 0.00144
#       127/1    1.42413    1.41905 +/- 0.00143
#       128/1    1.42237    1.41909 +/- 0.00141
#       129/1    1.41314    1.41902 +/- 0.00139
#       130/1    1.39620    1.41873 +/- 0.00141
#       131/1    1.43570    1.41894 +/- 0.00140
#       132/1    1.41802    1.41893 +/- 0.00139
#       133/1    1.40679    1.41878 +/- 0.00138
#       134/1    1.43057    1.41893 +/- 0.00137
#       135/1    1.41626    1.41889 +/- 0.00135
#       136/1    1.39924    1.41867 +/- 0.00136
#       137/1    1.42238    1.41871 +/- 0.00134
#       138/1    1.44861    1.41905 +/- 0.00137
#       139/1    1.40912    1.41894 +/- 0.00136
#       140/1    1.41190    1.41886 +/- 0.00134
#       141/1    1.42910    1.41897 +/- 0.00133
#       142/1    1.45264    1.41934 +/- 0.00137
#       143/1    1.43790    1.41954 +/- 0.00137
#       144/1    1.43079    1.41966 +/- 0.00136
#       145/1    1.42748    1.41974 +/- 0.00135
#       146/1    1.43014    1.41985 +/- 0.00134
#       147/1    1.41130    1.41976 +/- 0.00133
#       148/1    1.43972    1.41996 +/- 0.00133
#       149/1    1.41657    1.41993 +/- 0.00132
#       150/1    1.41771    1.41991 +/- 0.00130
#       151/1    1.42992    1.42000 +/- 0.00129
#       152/1    1.41465    1.41995 +/- 0.00128
#       153/1    1.40623    1.41982 +/- 0.00128
#       154/1    1.40789    1.41970 +/- 0.00127
#       155/1    1.42095    1.41972 +/- 0.00126
#       156/1    1.42673    1.41978 +/- 0.00125
#       157/1    1.41992    1.41978 +/- 0.00124
#       158/1    1.43116    1.41989 +/- 0.00123
#       159/1    1.42971    1.41998 +/- 0.00122
#       160/1    1.42253    1.42000 +/- 0.00121
#       161/1    1.40486    1.41987 +/- 0.00121
#       162/1    1.39473    1.41964 +/- 0.00122
#       163/1    1.44533    1.41987 +/- 0.00123
#       164/1    1.41382    1.41982 +/- 0.00122
#       165/1    1.43348    1.41993 +/- 0.00121
#       166/1    1.42517    1.41998 +/- 0.00120
#       167/1    1.43369    1.42010 +/- 0.00120
#       168/1    1.43003    1.42018 +/- 0.00119
#       169/1    1.42635    1.42023 +/- 0.00118
#       170/1    1.41371    1.42018 +/- 0.00117
#       171/1    1.41294    1.42012 +/- 0.00117
#       172/1    1.42331    1.42015 +/- 0.00116
#       173/1    1.42100    1.42015 +/- 0.00115
#       174/1    1.41456    1.42011 +/- 0.00114
#       175/1    1.43401    1.42022 +/- 0.00114
#       176/1    1.41397    1.42017 +/- 0.00113
#       177/1    1.41025    1.42009 +/- 0.00112
#       178/1    1.41679    1.42006 +/- 0.00111
#       179/1    1.41817    1.42005 +/- 0.00110
#       180/1    1.43569    1.42017 +/- 0.00110
#       181/1    1.41157    1.42010 +/- 0.00110
#       182/1    1.44214    1.42027 +/- 0.00110
#       183/1    1.42924    1.42034 +/- 0.00109
#       184/1    1.41495    1.42030 +/- 0.00109
#       185/1    1.41590    1.42027 +/- 0.00108
#       186/1    1.41193    1.42020 +/- 0.00107
#       187/1    1.40925    1.42012 +/- 0.00107
#       188/1    1.38963    1.41990 +/- 0.00108
#       189/1    1.42092    1.41991 +/- 0.00107
#       190/1    1.40712    1.41982 +/- 0.00107
#       191/1    1.41793    1.41981 +/- 0.00106
#       192/1    1.42649    1.41985 +/- 0.00106
#       193/1    1.43135    1.41993 +/- 0.00105
#       194/1    1.40569    1.41983 +/- 0.00105
#       195/1    1.40073    1.41970 +/- 0.00105
#       196/1    1.41859    1.41970 +/- 0.00104
#       197/1    1.42236    1.41971 +/- 0.00104
#       198/1    1.40128    1.41959 +/- 0.00104
#       199/1    1.42680    1.41964 +/- 0.00103
#       200/1    1.42427    1.41967 +/- 0.00103
#  Creating state point statepoint.200.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 7.6750e-01 seconds
#    Reading cross sections          = 7.4840e-01 seconds
#  Total time in simulation          = 3.5458e+01 seconds
#    Time in transport only          = 3.4948e+01 seconds
#    Time in inactive batches        = 7.6777e+00 seconds
#    Time in active batches          = 2.7780e+01 seconds
#    Time synchronizing fission bank = 2.8205e-01 seconds
#      Sampling source sites         = 2.4274e-01 seconds
#      SEND/RECV source sites        = 3.8678e-02 seconds
#    Time accumulating tallies       = 3.5088e-02 seconds
#    Time writing statepoints        = 6.7486e-03 seconds
#  Total time for finalization       = 1.4557e-03 seconds
#  Total time elapsed                = 3.6237e+01 seconds
#  Calculation Rate (inactive)       = 130247.0 particles/second
#  Calculation Rate (active)         = 107990.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.41950 +/- 0.00088
#  k-effective (Track-length)  = 1.41967 +/- 0.00103
#  k-effective (Absorption)    = 1.41914 +/- 0.00063
#  Combined k-effective        = 1.41925 +/- 0.00057
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
# get tally result and plot flux energy spectrum
sp = openmc.StatePoint('statepoint.200.h5')

flux_t = sp.get_tally(name='flux');
flux_df = flux_t.get_pandas_dataframe();
flux_vals = flux_df['mean'].to_numpy();

energy_x = 0.5*(energy_bins[0:-1]+energy_bins[1:])

plt.loglog(energy_x,flux_vals);
plt.grid();
plt.title('Baseline Neutron Spectrum in Fuel');
plt.xlabel('Energy [eV]');
plt.ylabel('flux [n/cm**2-s]');

# %%
# add neutron cross section data to provide context for the reaction tallys
OMC_DATA = "/home/sblair/OMC_DATA/endfb71_hdf5"  # work computer
#OMC_DATA = "/home/stu/OMC_DATA/endfb71_hdf5"    # personal computer

u238_path = OMC_DATA + "/U238.h5";
U238 = openmc.data.IncidentNeutron.from_hdf5(u238_path);
U238_capture = U238[102];

plt.rcParams['figure.figsize']=[12,8];
plt.loglog(energy_x,flux_vals,label='flux');
plt.loglog(U238_capture.xs['294K'].x,U238_capture.xs['294K'].y,label='U238 (n,\gamma)');
plt.grid();
plt.legend();
plt.xlabel('Energy [eV]')
plt.title('Flux and Capture Cross Section for U238');

# %%
u238_cap = sp.get_tally(name='u238_total_capture');
u238_cap_df = u238_cap.get_pandas_dataframe();

u233_abs = sp.get_tally(name='u233_abs');
u233_abs_df = u233_abs.get_pandas_dataframe();

# %%
u238_cap_vals = u238_cap_df['mean'].to_numpy();
u233_abs_vals = u233_abs_df['mean'].to_numpy();
tot_u238_capture = u238_cap_vals.sum();
tot_u233_abs = u233_abs_vals.sum(); 

print('Total U233 absorptions per source particle: %5.3f.' % tot_u233_abs);
print('U233 thermal absorptions: %5.3f ' % u233_abs_vals[0]);
print('U233 resonance absorptions: %5.3f' % u233_abs_vals[1]);
print('U233 high-energy absorptions: %5.3f' % u233_abs_vals[2]);

print('Total U238 captures per source particle: %5.3f' % tot_u238_capture);
print('U238 thermal captures: %5.3f ' % u238_cap_vals[0]);
print('U238 resonance captures: %5.3f ' % u238_cap_vals[1]);
print('U238 high-energy captures: %5.3f' % u238_cap_vals[2]);
# Out:
# Total U233 absorptions per source particle: 0.583.
# U233 thermal absorptions: 0.248
# U233 resonance absorptions: 0.305
# U233 high-energy absorptions: 0.030
# Total U238 captures per source particle: 0.341
# U238 thermal captures: 0.027
# U238 resonance captures: 0.275
# U238 high-energy captures: 0.038

# %%
print('Conversion ratio of U238 from high-energy neutrons: %5.3f ' % (u238_cap_vals[2]/tot_u233_abs));
print('Conversion ratio of U238 from neutrons in resonance energy region: %5.3f' % (u238_cap_vals[1]/tot_u233_abs));
print('Conversion ratio of U238 from neutrons in thermal energy region: %5.3f' % (u238_cap_vals[0]/tot_u233_abs));
print('Total initial conversion ratio: %5.3f' % (tot_u238_capture/tot_u233_abs));
# Out:
# Conversion ratio of U238 from high-energy neutrons: 0.066
# Conversion ratio of U238 from neutrons in resonance energy region: 0.472
# Conversion ratio of U238 from neutrons in thermal energy region: 0.046
# Total initial conversion ratio: 0.585
