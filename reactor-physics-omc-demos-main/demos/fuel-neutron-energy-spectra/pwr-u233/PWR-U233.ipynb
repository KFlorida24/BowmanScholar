# %% [markdown]
# # PWR U233
# This notebook is intended to compute the neutron energy spectrum and conversion ratio for a PWR similar to the baseline example, but fueled instead with U-233

# %%
import openmc
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
# define the fuel material
fuel = openmc.Material(name='fuel');
fuel.set_density('g/cm3',10.45);
# use atom fractions for 4 a/o U-233.
# estimate based on 4 a/o U-235 materials.xml file
fuel.add_nuclide('U233',0.040491);
fuel.add_nuclide('U234',0.000362);
fuel.add_nuclide('U236',0.0001855);
fuel.add_nuclide('U238',0.9589619);
fuel.add_nuclide('O16',2.0);

# ignore the gap gas (negligible impact on neutron energy)

# just use elemental Zirconium for clad.
clad = openmc.Material(name='clad');
clad.add_element('Zr',1);
clad.set_density('g/cm3',6.0);

mod = openmc.Material(name='moderator');
mod.add_element('O',1);
mod.add_element('H',2);
mod.set_density('g/cm3',0.712); #high temperature density
mod.add_s_alpha_beta('c_H_in_H2O');

# create Materials object and export to xml
materials = openmc.Materials([fuel,clad,mod]);
materials.export_to_xml();

# %%
# define the pin cell geometry
h_core = 500.;
h_fuel = 426.7;

r_o = 0.819/2.; #cm, fuel outer radius
r_ci = r_o +  0.008255; # clad inner radius 
r_co = 0.95/2.; # clad outer radius

P_D = 1.326;

pitch = P_D*(2*r_co);

#fuel cylinder
fuel_cyl = openmc.model.RightCircularCylinder([0.,0.,-h_fuel/2.],
                                             h_fuel,r_o);
fuel.volume = np.pi*(r_o**2)*h_fuel;

# clad inner cylinder
cladi_cyl = openmc.model.RightCircularCylinder([0.,0.,-h_fuel/2.],
                                              h_fuel,r_ci);
# clad outer cylinder
clado_cyl = openmc.model.RightCircularCylinder([0.,0.,-h_fuel/2.],
                                              h_fuel,r_co);
# pin cell container
core_cell = openmc.model.RectangularParallelepiped(-pitch/2.,pitch/2.,
                                                  -pitch/2.,pitch/2.,
                                                  -h_core/2.,h_core/2.,
                                                  boundary_type='reflective');


fuel_cell = openmc.Cell();
fuel_cell.region = -fuel_cyl
fuel_cell.fill = fuel;

gap_cell = openmc.Cell();
gap_cell.region = +fuel_cyl & -cladi_cyl;
gap_cell.fill = None; # same as "void"

clad_cell = openmc.Cell();
clad_cell.region = +cladi_cyl & -clado_cyl;
clad_cell.fill = clad;

mod_cell = openmc.Cell();
mod_cell.region = +clado_cyl & -core_cell;
mod_cell.fill = mod;

root_univ = openmc.Universe();
root_univ.add_cells([fuel_cell,gap_cell,clad_cell,mod_cell]);

geometry = openmc.Geometry();
geometry.root_universe = root_univ;

geometry.export_to_xml();

# %%
colors = {}
colors[fuel]='yellow'
colors[mod] = 'blue'
colors[clad] = 'grey'

root_univ.plot(width=(pitch,pitch),pixels=[400,400],
               color_by='material',colors=colors);

# %%
# create tally to determine flux energy spectrum in the fuel

cell_filter = openmc.CellFilter(fuel_cell);

# set up energy bins
N = 1001;
energy_bins = np.logspace(-3,7,num=N);
energy_filter = openmc.EnergyFilter(values=energy_bins);

# establish flux tally
flux = openmc.Tally(name='flux');
flux.scores = ['flux'];
flux.filters = [cell_filter,energy_filter];

# create a tally to estimate conversion ratio
# use cell_filter as before
u238_capture = openmc.Tally(name='u238_total_capture');
u238_capture.scores = ['(n,gamma)'];
u238_capture.nuclides=['U238']; #take this to be the only fertile nuclide
efilter_values = [0.0, 1.0, 3.0e4, 14.0e6]; # OpenMC energy units are eV
efilter_capture = openmc.EnergyFilter(values=efilter_values);
u238_capture.filters = [cell_filter, efilter_capture];

u233_abs = openmc.Tally(name='u233_abs');
u233_abs.scores = ['absorption'];
u233_abs.nuclides=['U233']; # take this to be the only fissile nuclide
u233_abs.filters = [cell_filter,efilter_capture]; # re-use the energy filter also



tallies = openmc.Tallies([flux, u238_capture, u233_abs]);
tallies.export_to_xml()

# %%
# establish settings for a criticality calculation
settings = openmc.Settings();
settings.run_mode = 'eigenvalue';
settings.particles = 20000;
settings.batches = 200;
settings.inactive = 50;

box = openmc.stats.Box(lower_left=(-r_o,-r_o,-h_fuel/2.),
                      upper_right = (r_o,r_o,h_fuel/2.),
                      only_fissionable=True);
src = openmc.Source(space=box);

settings.source = src;
settings.export_to_xml();

# %%
# run openmc
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.2
#           Git SHA1 | 37e74fb1e385478fdc25fdd0594b6f2cbb458d53
#          Date/Time | 2022-02-19 12:13:08
#     OpenMP Threads | 36
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U233 from /home/sblair/OMC_DATA/endfb71_hdf5/U233.h5
#  Reading U234 from /home/sblair/OMC_DATA/endfb71_hdf5/U234.h5
#  Reading U236 from /home/sblair/OMC_DATA/endfb71_hdf5/U236.h5
#  Reading U238 from /home/sblair/OMC_DATA/endfb71_hdf5/U238.h5
#  Reading O16 from /home/sblair/OMC_DATA/endfb71_hdf5/O16.h5
#  Reading Zr90 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr90.h5
#  Reading Zr91 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr91.h5
#  Reading Zr92 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr92.h5
#  Reading Zr94 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr94.h5
#  Reading Zr96 from /home/sblair/OMC_DATA/endfb71_hdf5/Zr96.h5
#  Reading O17 from /home/sblair/OMC_DATA/endfb71_hdf5/O17.h5
#  Reading H1 from /home/sblair/OMC_DATA/endfb71_hdf5/H1.h5
#  Reading H2 from /home/sblair/OMC_DATA/endfb71_hdf5/H2.h5
#  Reading c_H_in_H2O from /home/sblair/OMC_DATA/endfb71_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 294.0 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for Zr90
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.57517
#         2/1    1.56296
#         3/1    1.57809
#         4/1    1.60669
#         5/1    1.57485
#         6/1    1.60415
#         7/1    1.57696
#         8/1    1.58071
#         9/1    1.58296
#        10/1    1.59574
#        11/1    1.57702
#        12/1    1.59554
#        13/1    1.57660
#        14/1    1.58476
#        15/1    1.58054
#        16/1    1.60917
#        17/1    1.59374
#        18/1    1.58059
#        19/1    1.60360
#        20/1    1.60579
#        21/1    1.57188
#        22/1    1.58989
#        23/1    1.59794
#        24/1    1.58842
#        25/1    1.60006
#        26/1    1.58640
#        27/1    1.59344
#        28/1    1.57288
#        29/1    1.58089
#        30/1    1.58426
#        31/1    1.59704
#        32/1    1.57872
#        33/1    1.59082
#        34/1    1.57710
#        35/1    1.59914
#        36/1    1.58764
#        37/1    1.60923
#        38/1    1.58981
#        39/1    1.60940
#        40/1    1.56217
#        41/1    1.62153
#        42/1    1.59863
#        43/1    1.58950
#        44/1    1.58539
#        45/1    1.60829
#        46/1    1.55471
#        47/1    1.58228
#        48/1    1.58345
#        49/1    1.61217
#        50/1    1.56794
#        51/1    1.59052
#        52/1    1.57969    1.58511 +/- 0.00542
#        53/1    1.56669    1.57897 +/- 0.00689
#        54/1    1.59550    1.58310 +/- 0.00639
#        55/1    1.61200    1.58888 +/- 0.00761
#        56/1    1.59031    1.58912 +/- 0.00622
#        57/1    1.57078    1.58650 +/- 0.00587
#        58/1    1.59550    1.58762 +/- 0.00521
#        59/1    1.60532    1.58959 +/- 0.00500
#        60/1    1.58387    1.58902 +/- 0.00451
#        61/1    1.57848    1.58806 +/- 0.00419
#        62/1    1.57276    1.58678 +/- 0.00403
#        63/1    1.56492    1.58510 +/- 0.00407
#        64/1    1.59629    1.58590 +/- 0.00385
#        65/1    1.57182    1.58496 +/- 0.00371
#        66/1    1.58284    1.58483 +/- 0.00347
#        67/1    1.59979    1.58571 +/- 0.00338
#        68/1    1.58731    1.58580 +/- 0.00318
#        69/1    1.59493    1.58628 +/- 0.00305
#        70/1    1.59428    1.58668 +/- 0.00292
#        71/1    1.59492    1.58707 +/- 0.00281
#        72/1    1.61503    1.58834 +/- 0.00296
#        73/1    1.58262    1.58809 +/- 0.00284
#        74/1    1.59912    1.58855 +/- 0.00276
#        75/1    1.57042    1.58783 +/- 0.00274
#        76/1    1.58505    1.58772 +/- 0.00264
#        77/1    1.58117    1.58748 +/- 0.00255
#        78/1    1.59161    1.58763 +/- 0.00246
#        79/1    1.58911    1.58768 +/- 0.00238
#        80/1    1.58092    1.58745 +/- 0.00231
#        81/1    1.60153    1.58791 +/- 0.00228
#        82/1    1.57019    1.58735 +/- 0.00227
#        83/1    1.57510    1.58698 +/- 0.00223
#        84/1    1.60551    1.58753 +/- 0.00223
#        85/1    1.57012    1.58703 +/- 0.00223
#        86/1    1.56672    1.58646 +/- 0.00224
#        87/1    1.59434    1.58668 +/- 0.00218
#        88/1    1.59295    1.58684 +/- 0.00213
#        89/1    1.59612    1.58708 +/- 0.00209
#        90/1    1.59412    1.58726 +/- 0.00205
#        91/1    1.59875    1.58754 +/- 0.00201
#        92/1    1.59064    1.58761 +/- 0.00197
#        93/1    1.60823    1.58809 +/- 0.00198
#        94/1    1.57142    1.58771 +/- 0.00197
#        95/1    1.56785    1.58727 +/- 0.00198
#        96/1    1.58785    1.58728 +/- 0.00193
#        97/1    1.59802    1.58751 +/- 0.00191
#        98/1    1.59478    1.58766 +/- 0.00187
#        99/1    1.57689    1.58744 +/- 0.00185
#       100/1    1.55528    1.58680 +/- 0.00192
#       101/1    1.61953    1.58744 +/- 0.00199
#       102/1    1.59337    1.58756 +/- 0.00195
#       103/1    1.59477    1.58769 +/- 0.00192
#       104/1    1.60558    1.58802 +/- 0.00191
#       105/1    1.58892    1.58804 +/- 0.00188
#       106/1    1.58724    1.58802 +/- 0.00184
#       107/1    1.59691    1.58818 +/- 0.00182
#       108/1    1.60371    1.58845 +/- 0.00181
#       109/1    1.61396    1.58888 +/- 0.00183
#       110/1    1.57440    1.58864 +/- 0.00181
#       111/1    1.59457    1.58874 +/- 0.00179
#       112/1    1.58769    1.58872 +/- 0.00176
#       113/1    1.59445    1.58881 +/- 0.00173
#       114/1    1.59522    1.58891 +/- 0.00171
#       115/1    1.62034    1.58939 +/- 0.00175
#       116/1    1.58850    1.58938 +/- 0.00172
#       117/1    1.59508    1.58947 +/- 0.00170
#       118/1    1.58151    1.58935 +/- 0.00168
#       119/1    1.58014    1.58922 +/- 0.00166
#       120/1    1.60227    1.58940 +/- 0.00165
#       121/1    1.57653    1.58922 +/- 0.00163
#       122/1    1.61528    1.58958 +/- 0.00165
#       123/1    1.58124    1.58947 +/- 0.00163
#       124/1    1.57695    1.58930 +/- 0.00162
#       125/1    1.56790    1.58901 +/- 0.00162
#       126/1    1.57967    1.58889 +/- 0.00160
#       127/1    1.58182    1.58880 +/- 0.00159
#       128/1    1.61800    1.58917 +/- 0.00161
#       129/1    1.59892    1.58930 +/- 0.00159
#       130/1    1.57824    1.58916 +/- 0.00158
#       131/1    1.60053    1.58930 +/- 0.00157
#       132/1    1.59879    1.58941 +/- 0.00155
#       133/1    1.59782    1.58952 +/- 0.00154
#       134/1    1.59840    1.58962 +/- 0.00152
#       135/1    1.59155    1.58964 +/- 0.00150
#       136/1    1.56646    1.58937 +/- 0.00151
#       137/1    1.59752    1.58947 +/- 0.00150
#       138/1    1.58027    1.58936 +/- 0.00148
#       139/1    1.57627    1.58922 +/- 0.00147
#       140/1    1.60519    1.58939 +/- 0.00147
#       141/1    1.59960    1.58951 +/- 0.00146
#       142/1    1.56161    1.58920 +/- 0.00147
#       143/1    1.59904    1.58931 +/- 0.00146
#       144/1    1.60227    1.58945 +/- 0.00145
#       145/1    1.60456    1.58961 +/- 0.00144
#       146/1    1.57860    1.58949 +/- 0.00143
#       147/1    1.60200    1.58962 +/- 0.00142
#       148/1    1.59350    1.58966 +/- 0.00141
#       149/1    1.61340    1.58990 +/- 0.00142
#       150/1    1.57489    1.58975 +/- 0.00141
#       151/1    1.58313    1.58968 +/- 0.00140
#       152/1    1.59695    1.58976 +/- 0.00139
#       153/1    1.59269    1.58978 +/- 0.00137
#       154/1    1.58150    1.58970 +/- 0.00136
#       155/1    1.61116    1.58991 +/- 0.00136
#       156/1    1.59955    1.59000 +/- 0.00135
#       157/1    1.60776    1.59017 +/- 0.00135
#       158/1    1.56733    1.58995 +/- 0.00136
#       159/1    1.57765    1.58984 +/- 0.00135
#       160/1    1.57888    1.58974 +/- 0.00134
#       161/1    1.59422    1.58978 +/- 0.00133
#       162/1    1.59606    1.58984 +/- 0.00132
#       163/1    1.58239    1.58977 +/- 0.00131
#       164/1    1.60581    1.58991 +/- 0.00130
#       165/1    1.55917    1.58965 +/- 0.00132
#       166/1    1.58658    1.58962 +/- 0.00131
#       167/1    1.54723    1.58926 +/- 0.00135
#       168/1    1.60039    1.58935 +/- 0.00134
#       169/1    1.59282    1.58938 +/- 0.00133
#       170/1    1.56494    1.58918 +/- 0.00133
#       171/1    1.58778    1.58916 +/- 0.00132
#       172/1    1.58040    1.58909 +/- 0.00131
#       173/1    1.59836    1.58917 +/- 0.00130
#       174/1    1.60011    1.58926 +/- 0.00130
#       175/1    1.59086    1.58927 +/- 0.00129
#       176/1    1.58034    1.58920 +/- 0.00128
#       177/1    1.58236    1.58914 +/- 0.00127
#       178/1    1.59497    1.58919 +/- 0.00126
#       179/1    1.56576    1.58901 +/- 0.00126
#       180/1    1.57310    1.58889 +/- 0.00126
#       181/1    1.59160    1.58891 +/- 0.00125
#       182/1    1.59912    1.58898 +/- 0.00124
#       183/1    1.59307    1.58902 +/- 0.00123
#       184/1    1.55836    1.58879 +/- 0.00124
#       185/1    1.61822    1.58900 +/- 0.00125
#       186/1    1.58061    1.58894 +/- 0.00125
#       187/1    1.59826    1.58901 +/- 0.00124
#       188/1    1.58390    1.58897 +/- 0.00123
#       189/1    1.59998    1.58905 +/- 0.00122
#       190/1    1.60565    1.58917 +/- 0.00122
#       191/1    1.57349    1.58906 +/- 0.00122
#       192/1    1.57217    1.58894 +/- 0.00122
#       193/1    1.58794    1.58893 +/- 0.00121
#       194/1    1.58118    1.58888 +/- 0.00120
#       195/1    1.60236    1.58897 +/- 0.00120
#       196/1    1.60898    1.58911 +/- 0.00119
#       197/1    1.58458    1.58908 +/- 0.00119
#       198/1    1.58410    1.58905 +/- 0.00118
#       199/1    1.59803    1.58911 +/- 0.00117
#       200/1    1.57159    1.58899 +/- 0.00117
#  Creating state point statepoint.200.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 7.8370e-01 seconds
#    Reading cross sections          = 7.6810e-01 seconds
#  Total time in simulation          = 2.7707e+01 seconds
#    Time in transport only          = 2.7211e+01 seconds
#    Time in inactive batches        = 6.0226e+00 seconds
#    Time in active batches          = 2.1684e+01 seconds
#    Time synchronizing fission bank = 2.7401e-01 seconds
#      Sampling source sites         = 2.3652e-01 seconds
#      SEND/RECV source sites        = 3.6857e-02 seconds
#    Time accumulating tallies       = 4.2897e-02 seconds
#    Time writing statepoints        = 6.8137e-03 seconds
#  Total time for finalization       = 1.4342e-03 seconds
#  Total time elapsed                = 2.8506e+01 seconds
#  Calculation Rate (inactive)       = 166040.0 particles/second
#  Calculation Rate (active)         = 138351.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.58868 +/- 0.00092
#  k-effective (Track-length)  = 1.58899 +/- 0.00117
#  k-effective (Absorption)    = 1.58808 +/- 0.00061
#  Combined k-effective        = 1.58818 +/- 0.00059
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
# get tally result and plot flux energy spectrum
sp = openmc.StatePoint('statepoint.200.h5')

flux_t = sp.get_tally(name='flux');
flux_df = flux_t.get_pandas_dataframe();
flux_vals = flux_df['mean'].to_numpy();

energy_x = 0.5*(energy_bins[0:-1]+energy_bins[1:])

plt.loglog(energy_x,flux_vals);
plt.grid();
plt.title('Baseline Neutron Spectrum in Fuel');
plt.xlabel('Energy [eV]');
plt.ylabel('flux [n/cm**2-s]');

# %%
# add neutron cross section data to provide context for the reaction tallys
OMC_DATA = "/home/sblair/OMC_DATA/endfb71_hdf5"  # work computer
#OMC_DATA = "/home/stu/OMC_DATA/endfb71_hdf5"    # personal computer

u238_path = OMC_DATA + "/U238.h5";
U238 = openmc.data.IncidentNeutron.from_hdf5(u238_path);
U238_capture = U238[102];

plt.rcParams['figure.figsize']=[12,8];
plt.loglog(energy_x,flux_vals,label='flux');
plt.loglog(U238_capture.xs['294K'].x,U238_capture.xs['294K'].y,label='U238 (n,\gamma)');
plt.grid();
plt.legend();
plt.xlabel('Energy [eV]')
plt.title('Flux and Capture Cross Section for U238');

# %%
u238_cap = sp.get_tally(name='u238_total_capture');
u238_cap_df = u238_cap.get_pandas_dataframe();

u233_abs = sp.get_tally(name='u233_abs');
u233_abs_df = u233_abs.get_pandas_dataframe();

# %%
u238_cap_vals = u238_cap_df['mean'].to_numpy();
u233_abs_vals = u233_abs_df['mean'].to_numpy();
tot_u238_capture = u238_cap_vals.sum();
tot_u233_abs = u233_abs_vals.sum(); 

print('Total U233 absorptions per source particle: %5.3f.' % tot_u233_abs);
print('U233 thermal absorptions: %5.3f ' % u233_abs_vals[0]);
print('U233 resonance absorptions: %5.3f' % u233_abs_vals[1]);
print('U233 high-energy absorptions: %5.3f' % u233_abs_vals[2]);

print('Total U238 captures per source particle: %5.3f' % tot_u238_capture);
print('U238 thermal captures: %5.3f ' % u238_cap_vals[0]);
print('U238 resonance captures: %5.3f ' % u238_cap_vals[1]);
print('U238 high-energy captures: %5.3f' % u238_cap_vals[2]);
# Out:
# Total U233 absorptions per source particle: 0.670.
# U233 thermal absorptions: 0.434
# U233 resonance absorptions: 0.220
# U233 high-energy absorptions: 0.016
# Total U238 captures per source particle: 0.253
# U238 thermal captures: 0.048
# U238 resonance captures: 0.186
# U238 high-energy captures: 0.020

# %%
print('Conversion ratio of U238 from high-energy neutrons: %5.3f ' % (u238_cap_vals[2]/tot_u233_abs));
print('Conversion ratio of U238 from neutrons in resonance energy region: %5.3f' % (u238_cap_vals[1]/tot_u233_abs));
print('Conversion ratio of U238 from neutrons in thermal energy region: %5.3f' % (u238_cap_vals[0]/tot_u233_abs));
print('Total initial conversion ratio: %5.3f' % (tot_u238_capture/tot_u233_abs));
# Out:
# Conversion ratio of U238 from high-energy neutrons: 0.029
# Conversion ratio of U238 from neutrons in resonance energy region: 0.277
# Conversion ratio of U238 from neutrons in thermal energy region: 0.071
# Total initial conversion ratio: 0.377
